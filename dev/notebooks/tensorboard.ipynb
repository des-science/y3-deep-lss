# %%
import nersc_tensorboard_helper
# %load_ext tensorboard

# %%
# %tensorboard --logdir /pscratch/sd/a/athomsen/run_files/v3 --port 0
nersc_tensorboard_helper.tb_address()
# Out:
#       <iframe id="tensorboard-frame-b7809757f2fc04a9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b7809757f2fc04a9");
#           const url = new URL("/", window.location);
#           const port = 37773;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# <a href="https://jupyter.nersc.gov/user/athomsen/perlmutter-login-node-base/proxy/37773/">https://jupyter.nersc.gov/user/athomsen/perlmutter-login-node-base/proxy/37773/</a>

# %%
# %tensorboard --logdir /pscratch/sd/a/athomsen/run_files/v3/debug --port 0
nersc_tensorboard_helper.tb_address()
# Out:
#       <iframe id="tensorboard-frame-c9464ae37d246075" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c9464ae37d246075");
#           const url = new URL("/", window.location);
#           const port = 34565;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# <a href="https://jupyter.nersc.gov/user/athomsen/perlmutter-exclusive-node-gpu/proxy/34565/">https://jupyter.nersc.gov/user/athomsen/perlmutter-exclusive-node-gpu/proxy/34565/</a>
